# %% [markdown]
# <a href="https://colab.research.google.com/github/gowtham-dd/Data-Science-Basics/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pandas numpy matplotlib.pyplot must for seaborn
#we can use default dataser by using load_dataset()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset('tips')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x=data.total_bill,y=data.tip)
plt.show()

# %%
##count plot
sns.countplot(x=data.sex)## only 1 column enough it will count
plt.show()

# %% [markdown]
# ## HUE

# %%
sns.scatterplot(x=data.total_bill,y=data.tip,hue=data.sex)
plt.show()

# %%
hue_colors={"Yes":"black","No":"red"}

sns.scatterplot(x=data.total_bill,y=data.tip,hue=data.smoker,hue_order=["Yes","No"],palette=hue_colors)
plt.show()

# %% [markdown]
# ## Relational and Sub plots

# %% [markdown]
# ### Difference Between Relational Plot and Subplot in Seaborn
#
# **Relational Plot** and **Subplot** serve different purposes in data visualization using Seaborn and Matplotlib.
#
# **Relational Plot** is a high-level plotting function in Seaborn used to display relationships between two or more variables. It is especially useful for visualizing trends and patterns in datasets. Common types of relational plots include scatter plots and line plots. Seaborn’s `relplot()` function allows for automatic creation of multiple related plots (facets) based on categorical variables. This makes it ideal for comparing how relationships vary across subgroups of data, such as comparing trends by gender or time.
#
# On the other hand, a **Subplot** refers to the manual creation of multiple plot panels within a single figure using Matplotlib. It gives the user full control over the layout and appearance of each plot. Subplots are used when there is a need to display multiple different plots together in a customized grid arrangement, even if the plots are unrelated.
#
# In summary, **relational plots** are data-driven and automated for exploring relationships across variables, while **subplots** are layout-driven and manually arranged to organize multiple visualizations together.

# %%
## relational plot explain the relation between variables
#relplot()
# add a time row with it and show diff

sns.relplot(x=data.total_bill,y=data.tip,hue=data.smoker,col=data.sex,row=data.time)
plt.show()

# %%
## subplot uses extra column and row
sns.relplot(x=data.total_bill,y=data.tip,hue=data.smoker,col=data.smoker,row=data.sex,kind='scatter')
plt.show()

# %%
## subplot uses extra column and row
sns.relplot(x=data.total_bill,y=data.tip,hue=data.smoker,col=data.smoker,row=data.day,kind='scatter')
plt.show()

# %% [markdown]
# ## wrapping and ordering

# %%
sns.relplot(x=data.total_bill,y=data.tip,hue=data.smoker,col=data.day,kind='scatter',col_wrap=4,col_order=['Sun','Sat','Fri','Thur'])
plt.show()
##col_warp
##col_order and row cant be used at a time

# %% [markdown]
# ## Size

# %%
## subplot uses extra column and row
#size give dark color to large used data use alpha to transperency
sns.relplot(data=data, x='total_bill', y='tip', col='smoker', row='sex', kind='scatter', size='size', hue='size')
plt.show()

# %%
sns.relplot(
    data=data,
    x='total_bill',
    y='tip',
    col='smoker',
    row='sex',
    kind='scatter',
    hue='size',
    size='size',
    alpha=0.6
)
plt.show()

# %% [markdown]
# ## Lines

# %%
# just change kind to line
sns.relplot(
    data=data,
    x='total_bill',
    y='tip',
    hue='day',
    markers=True,
    kind='line',
    dashes=False

)
plt.show()

# %%
sns.relplot(
    data=data,
    x='day',
    y='total_bill',
    kind='scatter'
)

plt.show()

sns.relplot(
    data=data,
    x='day',
    y='total_bill',
    kind='line'
)
# gives default mean region that is shaded
#low standard Deviation best decision making
plt.show()
sns.relplot(
    data=data,
    x='day',
    y='total_bill',
    kind='line',
    ci=None
)

plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/axisgrid.py:854: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# ## Cat Plot

# %%
sns.catplot(data=data,x='day',y='total_bill',kind='box')
plt.show()

sns.catplot(data=data,x='sex',kind='count')
plt.show()

sns.catplot(data=data,x='day',y='total_bill',kind='bar')
plt.show()

sns.catplot(data=data,x='day',y='total_bill',kind='violin')
plt.show()

sns.catplot(data=data,x='day',y='total_bill',kind='violin',inner='quartile')
plt.show()

sns.catplot(data=data,x='day',y='total_bill',kind='swarm')
plt.show()

# %% [markdown]
# ## Bar Plot

# %%
#1 category needed
sns.barplot(data=data,x='day',y='total_bill')
plt.show()

sns.barplot(data=data,x='day',y='total_bill',ci=None)
plt.show()

#to change vertical to horizontal change x and y

sns.barplot(data=data,y='day',x='total_bill',ci=None)
plt.show()
# Out:
# <ipython-input-45-d5db31a711d9>:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data,x='day',y='total_bill',ci=None)
# <ipython-input-45-d5db31a711d9>:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=data,y='day',x='total_bill',ci=None)

# %% [markdown]
# ## Box

# %%
sns.catplot (data=data,x='day',y='total_bill',kind='box')
plt.show()

#whis aks whishkers that is the box in middle can be changed
# default is 1.5 u can extend upto 2.0 whis=2.0
# showing percentile whis=[5,95]

sns.catplot(data=data,x='day',y='total_bill',kind='box',whis=[5,95])
plt.show()


sns.catplot(data=data,x='day',y='total_bill',kind='box',whis=2.0)
plt.show()

# %% [markdown]
# ## Point Plot

# %%
from numpy import median as median
# same as line but both  x y shld be categorical data
#shows mean value of the quantitble variable
sns.catplot(data=data,x='day',y='total_bill',kind='point')
plt.show()
#join= false to remove join
sns.catplot(data=data,x='day',y='total_bill',kind='point',join=False)
plt.show()
#to display mediam use numpy import median and in attribute use estimator
#default it uses mean
#cap ie the top circle can be used by capsize
#set_style("") to style
sns.set_style("whitegrid")
sns.catplot(data=data,x='day',y='total_bill',kind='point',join=False)
plt.show()
# Out:
# <ipython-input-55-2222275429c0>:7: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.catplot(data=data,x='day',y='total_bill',kind='point',join=False)
# <ipython-input-55-2222275429c0>:14: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.catplot(data=data,x='day',y='total_bill',kind='point',join=False)

# %% [markdown]
# ## Palette

# %%
#sns.set_palette()

sns.set_palette("RdBu")
sns.catplot(data=data,x='day',y='total_bill',kind='bar')
plt.show()

# %%
custom_palette=['red','blue','green']

sns.set_palette(custom_palette)
sns.barplot(data=data,x='day',y='total_bill')
plt.show()

# %%
#Scale
# paper notebook talk poster

sns.set_context("paper")
sns.barplot(data=data,x='day',y='total_bill')
plt.show()

sns.set_context("notebook")
sns.barplot(data=data,x='day',y='total_bill')
plt.show()

sns.set_context("talk")
sns.barplot(data=data,x='day',y='total_bill')
plt.show()

sns.set_context("poster")
sns.barplot(data=data,x='day',y='total_bill')
plt.show()

# %%
sns.set_palette('RdBu')
sns.countplot(data=data,x='sex')
# Out:
# <Axes: xlabel='sex', ylabel='count'>
