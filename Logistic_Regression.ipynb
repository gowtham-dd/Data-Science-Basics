# %% [markdown]
# <a href="https://colab.research.google.com/github/gowtham-dd/Data-Science-Basics/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LOGISTIC REGRESSION
#
# 1.KNN
#
# 2.Decision tree,RF,
#
# 3.Naive Bays

# %%
#logistic regression is a classification algorithm
#specifically designed for binary class so trarget should be either or
#mathematically log mari but logictic na movement
#linear regression + sigmoid function - logistic regression
#sigmoid fn- s curve within 0 to 1
#f(Z) = 1/1+e^-z so always value will be less than 1
#here evaluation will not work

# %%
import pandas as pd
dia=pd.read_csv("https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/main/diabetes.csv")
dia
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
featured=dia[['BloodPressure','Glucose','Insulin','BMI']]
target=dia['Outcome']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(featured,target,test_size=0.2,random_state=42)

from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
# prompt: create a dataframe for y pred and y test

import pandas as pd

# Assuming y_pred and y_test are already defined from your previous code

df_results = pd.DataFrame({'y_pred': y_pred, 'y_test': y_test})
df_results
# Out:
#      y_pred  y_test
# 668       0       0
# 324       0       0
# 624       0       0
# 690       0       0
# 473       0       0
# ..      ...     ...
# 355       1       1
# 534       0       0
# 344       0       0
# 296       0       1
# 462       0       0
#
# [154 rows x 2 columns]

# %%
from sklearn.metrics import classification_report
y_pred=model.predict(x_test)
print(classification_report(y_test,y_pred)) #(actual,predict)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.86      0.82        99
#            1       0.70      0.58      0.63        55
#
#     accuracy                           0.76       154
#    macro avg       0.74      0.72      0.73       154
# weighted avg       0.75      0.76      0.75       154

# %%
# prompt: do a crostab with ytest and ypred

import pandas as pd
# ... (Your existing code)

# Assuming y_pred and y_test are already defined from your previous code

df_results = pd.DataFrame({'y_pred': y_pred, 'y_test': y_test})

# Create the cross-tabulation
cross_tab = pd.crosstab(df_results['y_test'], df_results['y_pred'])
cross_tab
# Out:
# y_pred   0   1
# y_test
# 0       85  14
# 1       23  32

# %%
# prompt: draw confusion matrix

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# f1- score
#
#  True +ve , True -ve, False +ve , False -ve

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/refs/heads/main/ChurnData.csv')
data
# Out:
#      tenure   age  address  income   ed  employ  equip  callcard  wireless  \
# 0      11.0  33.0      7.0   136.0  5.0     5.0    0.0       1.0       1.0
# 1      33.0  33.0     12.0    33.0  2.0     0.0    0.0       0.0       0.0
# 2      23.0  30.0      9.0    30.0  1.0     2.0    0.0       0.0       0.0
# 3      38.0  35.0      5.0    76.0  2.0    10.0    1.0       1.0       1.0
# 4       7.0  35.0     14.0    80.0  2.0    15.0    0.0       1.0       0.0
# ..      ...   ...      ...     ...  ...     ...    ...       ...       ...
# 195    55.0  44.0     24.0    83.0  1.0    23.0    0.0       1.0       0.0
# 196    34.0  23.0      3.0    24.0  1.0     7.0    0.0       1.0       0.0
# 197     6.0  32.0     10.0    47.0  1.0    10.0    0.0       1.0       0.0
# 198    24.0  30.0      0.0    25.0  4.0     5.0    0.0       1.0       1.0
# 199    61.0  50.0     16.0   190.0  2.0    22.0    1.0       1.0       1.0
#
# ...

# %%
# prompt: corelation heat map for data

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' DataFrame is already loaded as shown in your previous code
# data = pd.read_csv('https://raw.githubusercontent.com/nethajinirmal13/Training-datasets/refs/heads/main/ChurnData.csv')

# Select numerical features for correlation analysis (adjust as needed)
numerical_features = data.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numerical_features.corr()

# Create the heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
features=data[['tenure','income','wireless']]
target=data['churn']

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=71)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report
y_pred=model.predict(x_test)
print(classification_report(y_test,y_pred)) #(actual,predict)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.94      0.91        31
#          1.0       0.71      0.56      0.62         9
#
#     accuracy                           0.85        40
#    macro avg       0.80      0.75      0.77        40
# weighted avg       0.84      0.85      0.84        40

# %%
# prompt: do a crostab with ytest and ypred

import pandas as pd
# ... (Your existing code)

# Assuming y_pred and y_test are already defined from your previous code

df_results = pd.DataFrame({'y_pred': y_pred, 'y_test': y_test})

# Create the cross-tabulation
cross_tab = pd.crosstab(df_results['y_test'], df_results['y_pred'])
cross_tab
# Out:
# y_pred  0.0  1.0
# y_test
# 0.0      29    2
# 1.0       4    5

# %%
# prompt: draw confusion matrix

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
